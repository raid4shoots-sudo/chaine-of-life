# %% [markdown]
# <a href="https://colab.research.google.com/github/raid4shoots-sudo/chaine-of-life/blob/main/TP_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TP1 – Prise en main de Google Colab et bibliothèques IA
#
# **Nom et Prénom :** Raid Khennane
#
# **Date :** 17/02/2026

# %%
print("Bienvenue dans le TP élément d’IA appliqué")
# Out:
# Bienvenue dans le TP élément d’IA appliqué

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/TP_AI/Data.csv'
AI = pd.read_csv(path)

# %%
AI.head()
# Out:
#          date     produit  ventes
# 0  2025-11-01  Ordinateur    1250
# 1  2025-11-01      Souris      22
# 2  2025-11-01     Clavier      63
# 3  2025-11-01       Écran     410
# 4  2025-11-01  Imprimante     255

# %%
AI.shape
# Out:
# (59, 3)

# %%
AI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     59 non-null     object
#  1   produit  59 non-null     object
#  2   ventes   59 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.5+ KB

# %%
AI.describe()
# Out:
#             ventes
# count    59.000000
# mean    450.000000
# std     454.626979
# min      22.000000
# 25%      73.500000
# 50%     255.000000
# 75%     870.000000
# max    1500.000000

# %%
AI['ventes'].mean()
# Out:
# np.float64(450.0)

# %%
AI['ventes'].median()
# Out:
# 255.0

# %%
AI['ventes'].std()
# Out:
# 454.6269785826314

# %%
AI.isnull().sum()
# Out:
# date       0
# produit    0
# ventes     0
# dtype: int64

# %%
plt.figure(figsize=(10, 10))
plt.hist(AI['produit'], bins=20)
plt.xlabel("produit")
plt.ylabel("nombre")
plt.title("Histogramme de produit")
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.boxplot(x=AI['produit'])
plt.title("Boxplot de les produit")
plt.show()

# %%
plt.figure()
sns.heatmap(AI.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Heatmap de corrélation")
plt.show()

# %%
AI_clean = AI.dropna(subset=['ventes'])
AI_filtered = AI_clean[AI_clean['ventes'] > 50]
AI_filtered.head()
# Out:
#          date     produit  ventes
# 0  2025-11-01  Ordinateur    1250
# 2  2025-11-01     Clavier      63
# 3  2025-11-01       Écran     410
# 4  2025-11-01  Imprimante     255
# 5  2025-11-01    Tablette     820
